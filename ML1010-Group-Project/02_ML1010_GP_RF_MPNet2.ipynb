# %% [markdown]
# # Configuration

# %%
# Parameters
ENABLE_COLAB = False

PROJECT_NAME = 'ML1010-Group-Project'
EXPERIMENT_NAME = 'ReviewText_Lemma_MPNet2 (Random Forest)'
FILE_NAME = '01_ML1010_GP_RF_MPNet2'
LOAD_FROM_EXP = False

#Root Machine Learning Directory. Projects appear underneath
GOOGLE_DRIVE_MOUNT = '/content/gdrive' 
COLAB_ROOT_DIR = GOOGLE_DRIVE_MOUNT + '/MyDrive/Colab Notebooks'
COLAB_INIT_DIR = COLAB_ROOT_DIR + '/utility_files'

LOCAL_ROOT_DIR = '/home/magni//ML_Root/project_root'
LOCAL_INIT_DIR = LOCAL_ROOT_DIR + '/utility_files'

# %% [markdown]
# # Bootstrap Environment

# %%
#add in support for utility file directory and importing
import sys
import os

if ENABLE_COLAB:
  #Need access to drive
  from google.colab import drive
  drive.mount(GOOGLE_DRIVE_MOUNT, force_remount=True)
  
  #add in utility directory to syspath to import 
  INIT_DIR = COLAB_INIT_DIR
  sys.path.append(os.path.abspath(INIT_DIR))
  
  #Config environment variables
  ROOT_DIR = COLAB_ROOT_DIR
  
else:
  #add in utility directory to syspath to import
  INIT_DIR = LOCAL_INIT_DIR
  sys.path.append(os.path.abspath(INIT_DIR))
  
  #Config environment variables
  ROOT_DIR = LOCAL_ROOT_DIR

#Import Utility Support
from jarvis import Jarvis
jarvis = Jarvis(ROOT_DIR, PROJECT_NAME)

import mv_python_utils as mvutils
# Out:
# Wha...where am I?
# I am awake now.
#
# I have set your current working directory to /home/magni/ML_Root/project_root/ML1010-Group-Project
# The current time is 16:34
# Hello sir. Reminder, no more coffee.

# %% [markdown]
# # Setup Runtime Environment

# %%
if ENABLE_COLAB:
  #!pip install scipy -q
  #!pip install scikit-learn -q
  #!pip install pycaret -q
  #!pip install matplotlib -q
  #!pip install joblib -q
  #!pip install pandasql -q
  # !pip install umap_learn -q
  # !pip install sentence_transformers -q
  # !pip install spacytextblob -q
  # !pip install flair -q
  display('Google Colab enabled')
else:
  display('Google Colab not enabled')

#Common imports
import json
import pandas as pd
import numpy as np
import matplotlib
import re
import nltk
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split as tts
#from yellowbrick.classifier import ConfusionMatrix
#from sklearn.linear_model import LogisticRegression
from yellowbrick.target import ClassBalance
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

nltk.download('stopwords')
# %matplotlib inline
# Out:
# 'Google Colab not enabled'
# [nltk_data] Downloading package stopwords to /home/magni/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import importlib
import cw_df_metric_utils as cwutils
import DataPackage as dp
import DataPackageSupport as dps
import DataExperiment
import DataExperimentSupport
# Out:
# 2022-01-22 16:35:03.435621: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-22 16:35:03.435651: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
importlib.reload(dp)
importlib.reload(dps)
importlib.reload(DataExperiment)
importlib.reload(DataExperimentSupport)
# Out:
# <module 'DataExperimentSupport' from '/home/magni/ML_Root/project_root/utility_files/DataExperimentSupport.py'>

# %% [markdown]
# # Load Data

# %%
#axis_labels=[1,2,3,4,5]
axis_labels=[0,1]
classifier = RandomForestClassifier()
ANALSYSIS_COL = 'reviewText_lemma_mpnet'
UNIQUE_COL = 'uuid'
TARGET_COL = 'overall_posneg'

# %%
if LOAD_FROM_EXP:
    #start from saved state
    myExp = jarvis.loadExperiment(FILE_NAME)
    myExp.display()

else:
    #start from source file and regenerate
    testDf = pd.read_pickle(jarvis.DATA_DIR_WORK + "/01_NL_ReviewText_All(new).pkl.gz")

    testDfBert = cwutils.getBertEncodeFrame(df=testDf,
                                            bertColumn=ANALSYSIS_COL,
                                            uniqueColumn=UNIQUE_COL,
                                            otherColumns=[TARGET_COL]
                                            )



    myExp = DataExperiment.DataExperiment(projectName=PROJECT_NAME,
                                          experimentName=EXPERIMENT_NAME,
                                          origData=testDfBert,
                                          uniqueColumn=UNIQUE_COL,
                                          targetColumn=TARGET_COL,
                                          classifier=classifier)
# Out:
# DataExperiment summary:
# ---> projectName: ML1010-Group-Project
# ---> experimentName: ReviewText_Lemma_MPNet2 (Random Forest)
# ---> isDataPackageLoaded: True
# ---> isBaseModelLoaded: False
# ---> isBaseModelPredicted: False
# ---> isBaseModelLearningCurveCreated: False
# ---> isFinalModelLoaded: False
# ---> isFinalModelPredicted: False
# ---> isFinalModelLearningCurveCreated: False
# ---> isClassifierLoaded: True
# RandomForestClassifier()
#
#     DataPackage summary:
#     Attributes:
#     ---> uniqueColumn: uuid
#     ---> targetColumn: overall_posneg
#     Process:
#     ---> isBalanced: False
#     ---> isTrainTestSplit: False
#     Data:
#     ---> isOrigDataLoaded: True
#     ---> isTrainDataLoaded: False
#     ---> isTestDataLoaded: False

# %%
#myExp.processDataPackage()
myExp.dataPackage.classBalanceUndersample()
myExp.dataPackage.splitTrainTest()
# Out:
# Undersampling data to match min class: 0 of size: 13440
#    overall_posneg  ttlCol
# 0               0   13440
# 1               1   13440
# Completed train/test split (train_size = 0.8):
# ---> Original data size: 26880
# ---> Training data size: 21504
# ---> Testing data size: 5376
# ---> Stratified on column: overall_posneg

# %%
myExp.createBaseModel()
# Out:
# Base Model Stats:
# Accuracy: 0.8
# Precision: 0.8
# Recalll: 0.8
# F1 Score: 0.8
# Cohen kappa:: 0.6

# %%
myExp.analyzeBaseModelFeatureImportance(returnAbove=0.002)
# Out:
#   0%|          | 0/101 [00:00<?, ?it/s]
# Feature Importance Summary:
# ---> Original feature count: 768
# ---> Returned feature count: 82
# ---> Removed feature count: 686
# ---> Return items above (including): 0.002
#     feature_idx  importance
# 0             0    0.003341
# 1            10    0.002524
# 2            15    0.004750
# 3            22    0.002702
# 4            43    0.003251
# ..          ...         ...
# 77          662    0.002711
# 78          693    0.002728
# 79          706    0.010375
# 80          726    0.003641
# 81          751    0.003487
#
# [82 rows x 2 columns]

# %%
myExp.createFinalModel(featureImportanceThreshold=0.002)
# Out:
#   0%|          | 0/101 [00:00<?, ?it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
# Final Model Stats:
# Accuracy: 0.8
# Precision: 0.8
# Recalll: 0.8
# F1 Score: 0.8
# Cohen kappa:: 0.61

# %%
myExp.createBaseModelLearningCurve(n_jobs=10)
# Out:
# [learning_curve] Training set sizes: [ 1720  3440  8601 17203]
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   3 out of  20 | elapsed:   21.0s remaining:  2.0min
# [Parallel(n_jobs=10)]: Done   9 out of  20 | elapsed:   50.8s remaining:  1.0min
# [Parallel(n_jobs=10)]: Done  15 out of  20 | elapsed:  2.0min remaining:   40.9s
# [Parallel(n_jobs=10)]: Done  20 out of  20 | elapsed:  3.5min finished

# %%
myExp.createFinalModelLearningCurve(n_jobs=10)
# Out:
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [learning_curve] Training set sizes: [ 1720  3440  8601 17203]
# [Parallel(n_jobs=10)]: Done   3 out of  20 | elapsed:    5.0s remaining:   28.5s
# [Parallel(n_jobs=10)]: Done   9 out of  20 | elapsed:   15.3s remaining:   18.8s
# [Parallel(n_jobs=10)]: Done  15 out of  20 | elapsed:   36.6s remaining:   12.2s
# [Parallel(n_jobs=10)]: Done  20 out of  20 | elapsed:   58.7s finished

# %%
myExp.showBaseModelReport(axis_labels,
                          upperValue=0.025)
# Out:
# Base Model Stats:
# Accuracy: 0.8
# Precision: 0.8
# Recalll: 0.8
# F1 Score: 0.8
# Cohen kappa:: 0.6
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.80      2688
#            1       0.82      0.77      0.79      2688
#
#     accuracy                           0.80      5376
#    macro avg       0.80      0.80      0.80      5376
# weighted avg       0.80      0.80      0.80      5376
# /home/magni/python_env/ML1010_env2/lib64/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# /home/magni/python_env/ML1010_env2/lib64/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# Base model ROCAUC not calculated. Starting now
#   0%|          | 0/251 [00:00<?, ?it/s]
# /home/magni/python_env/ML1010_env2/lib64/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# <lime.lime_tabular.LimeTabularExplainer object at 0x7f7518f26290>
# /home/magni/python_env/ML1010_env2/lib64/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
# /home/magni/python_env/ML1010_env2/lib64/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
# predicted [0]
# actual 1
# [CV] END ..................., score=(train=0.979, test=0.803) total time= 1.4min
# [CV] END ..................., score=(train=0.983, test=0.790) total time=   6.2s
# [CV] END ..................., score=(train=0.982, test=0.781) total time=   9.4s
# [CV] END ..................., score=(train=0.983, test=0.787) total time=   9.7s
# [CV] END ..................., score=(train=0.979, test=0.794) total time= 1.3min
# [CV] END ..................., score=(train=0.981, test=0.792) total time=  19.9s
# [CV] END ..................., score=(train=0.982, test=0.788) total time=  15.3s
# [CV] END ..................., score=(train=0.982, test=0.775) total time=  16.1s
# [CV] END ..................., score=(train=0.982, test=0.782) total time=  11.4s
# [CV] END ..................., score=(train=0.983, test=0.793) total time=  20.1s
# [CV] END ..................., score=(train=0.978, test=0.809) total time= 2.3min
# [CV] END ..................., score=(train=0.983, test=0.785) total time=   6.6s
# [CV] END ..................., score=(train=0.980, test=0.780) total time=  13.4s
# [CV] END ..................., score=(train=0.981, test=0.794) total time= 1.3min
# [CV] END ..................., score=(train=0.984, test=0.783) total time=   3.4s
# [CV] END ..................., score=(train=0.979, test=0.799) total time=  18.0s
# [CV] END ..................., score=(train=0.983, test=0.790) total time=  20.3s
# [CV] END ..................., score=(train=0.980, test=0.788) total time= 1.3min
# [CV] END ..................., score=(train=0.979, test=0.799) total time=  36.1s
# [CV] END ..................., score=(train=0.977, test=0.810) total time= 2.6min
# [CV] END ..................., score=(train=0.982, test=0.789) total time=   9.9s
# [CV] END ..................., score=(train=0.982, test=0.787) total time=   5.1s
# [CV] END ..................., score=(train=0.979, test=0.791) total time=  21.3s
# [CV] END ..................., score=(train=0.983, test=0.779) total time=  13.3s
# [CV] END ..................., score=(train=0.978, test=0.798) total time= 2.6min
# [CV] END ..................., score=(train=0.977, test=0.806) total time=  39.7s
# [CV] END ..................., score=(train=0.983, test=0.785) total time=  29.5s
# [CV] END ..................., score=(train=0.978, test=0.791) total time= 2.8min
# [CV] END ..................., score=(train=0.983, test=0.781) total time=   4.8s
# [CV] END ..................., score=(train=0.981, test=0.777) total time=   2.4s
# [CV] END ..................., score=(train=0.978, test=0.796) total time=  35.7s
# [CV] END ..................., score=(train=0.984, test=0.784) total time=  15.5s
# [CV] END ..................., score=(train=0.982, test=0.781) total time=  28.5s
# [CV] END ..................., score=(train=0.979, test=0.798) total time= 1.2min
# [CV] END ..................., score=(train=0.983, test=0.783) total time=   4.7s
# [CV] END ..................., score=(train=0.978, test=0.795) total time=  40.2s
# [CV] END ..................., score=(train=0.979, test=0.803) total time= 2.7min
# [CV] END ..................., score=(train=0.979, test=0.799) total time=  12.2s
# [CV] END ..................., score=(train=0.983, test=0.798) total time=   3.3s
# [CV] END ..................., score=(train=0.978, test=0.803) total time=  41.9s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_171426/3855762138.py in <module>
#       1 myExp.showBaseModelReport(axis_labels,
# ----> 2                           upperValue=0.025)
#
# ~/ML_Root/project_root/utility_files/DataExperiment.py in showBaseModelReport(self, axisLabels, startValue, increment, upperValue, useLasso, topn)
#     428                                             topn=topn)
#     429         self.showBaseLimeGlobalImportance()
# --> 430         self.showBaseLimeLocalImportance()
#     431
#     432     def showBaseModelROCAUC(self, axisLabels, useStored=False):
#
# ~/ML_Root/project_root/utility_files/DataExperiment.py in showBaseLimeLocalImportance(self)
#     676                                     YTest=self.dataPackage.getYTestData(),
#     677                                     features=self.dataPackage.dataFeatures,
# --> 678                                     mode='classification')
#     679
#     680     def showFinalLimeGlobalImportance(self):
#
# ~/ML_Root/project_root/utility_files/DataExperimentSupport.py in showLimeLocalImportance(XTrain, YTrain, XTest, YTest, features, mode)
#     514     print(f'actual {YTest[idx]}')
#     515
# --> 516     explanation = explainer.explain_instance(XTest[idx], lr.predict_proba)
#     517
#     518     explanation.show_in_notebook()
#
# ~/python_env/ML1010_env2/lib64/python3.7/site-packages/lime/lime_tabular.py in explain_instance(self, data_row, predict_fn, labels, top_labels, num_features, num_samples, distance_metric, model_regressor)
#     338             # Preventative code: if sparse, convert to csr format if not in csr format already
#     339             data_row = data_row.tocsr()
# --> 340         data, inverse = self.__data_inverse(data_row, num_samples)
#     341         if sp.sparse.issparse(data):
#     342             # Note in sparse case we don't subtract mean since data would become dense
#
# ~/python_env/ML1010_env2/lib64/python3.7/site-packages/lime/lime_tabular.py in __data_inverse(self, data_row, num_samples)
#     548             inverse[:, column] = inverse_column
#     549         if self.discretizer is not None:
# --> 550             inverse[1:] = self.discretizer.undiscretize(inverse[1:])
#     551         inverse[0] = data_row
#     552         return data, inverse
#
# ~/python_env/ML1010_env2/lib64/python3.7/site-packages/lime/discretize.py in undiscretize(self, data)
#     143             else:
#     144                 ret[:, feature] = self.get_undiscretize_values(
# --> 145                     feature, ret[:, feature].astype(int)
#     146                 )
#     147         return ret
#
# ~/python_env/ML1010_env2/lib64/python3.7/site-packages/lime/discretize.py in get_undiscretize_values(self, feature, values)
#     130             loc=means[min_max_unequal],
#     131             scale=stds[min_max_unequal],
# --> 132             random_state=self.random_state
#     133         )
#     134         return ret
#
# ~/python_env/ML1010_env2/lib64/python3.7/site-packages/scipy/stats/_distn_infrastructure.py in rvs(self, *args, **kwds)
#    1090             vals = self._rvs(*args)
#    1091         else:
# -> 1092             vals = self._rvs(*args, size=size, random_state=random_state)
#    1093
#    1094         vals = vals * scale + loc
#
# ~/python_env/ML1010_env2/lib64/python3.7/site-packages/scipy/stats/_continuous_distns.py in _rvs(self, a, b, size, random_state)
#    8298                             for j in range(-len(size), 0))
#    8299                 out[idx] = self._rvs_scalar(it[0], it[1], numsamples,
# -> 8300                                             random_state).reshape(shp)
#    8301                 it.iternext()
#    8302
#
# ~/python_env/ML1010_env2/lib64/python3.7/site-packages/scipy/stats/_continuous_distns.py in _rvs_scalar(self, a, b, numsamples, random_state)
#    8314         # Calculate some rvs
#    8315         U = random_state.uniform(low=0, high=1, size=N)
# -> 8316         x = self._ppf(U, a, b)
#    8317         rvs = np.reshape(x, size1d)
#    8318         return rvs
#
# ~/python_env/ML1010_env2/lib64/python3.7/site-packages/scipy/stats/_continuous_distns.py in _ppf(self, q, a, b)
#    8188         a, b = np.atleast_1d(a), np.atleast_1d(b)
#    8189         if a.size == 1 and b.size == 1:
# -> 8190             return _truncnorm_ppf_scalar(q, a.item(), b.item())
#    8191
#    8192         out = None
#
# ~/python_env/ML1010_env2/lib64/python3.7/site-packages/scipy/stats/_continuous_distns.py in _truncnorm_ppf_scalar(q, a, b)
#    8068                 x = [optimize.zeros.brentq(_f_sf, a, b, args=(c,),
#    8069                                            maxiter=TRUNCNORM_MAX_BRENT_ITERS)
# -> 8070                      for c in values]
#    8071                 np.place(out, cond_inner, x)
#    8072         out[out < a] = a
#
# ~/python_env/ML1010_env2/lib64/python3.7/site-packages/scipy/stats/_continuous_distns.py in <listcomp>(.0)
#    8068                 x = [optimize.zeros.brentq(_f_sf, a, b, args=(c,),
#    8069                                            maxiter=TRUNCNORM_MAX_BRENT_ITERS)
# -> 8070                      for c in values]
#    8071                 np.place(out, cond_inner, x)
#    8072         out[out < a] = a
#
# ~/python_env/ML1010_env2/lib64/python3.7/site-packages/scipy/optimize/zeros.py in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     774     if rtol < _rtol:
#     775         raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 776     r = _zeros._brentq(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     777     return results_c(full_output, r)
#     778
#
# ValueError: f(a) and f(b) must have different signs

# %%
myExp.showFinalModelReport(axis_labels,
                           startValue=0.01,
                           increment=0.001,
                           upperValue=0.03)

# %%
myExp.display()

# %% [markdown]
# #  Save Experiment

# %%
jarvis.saveExperiment(myExp, FILE_NAME)

# %% [markdown]
# #  Scratchpad

# %%
importlib.reload(dp)
importlib.reload(dps)
importlib.reload(DataExperiment)
importlib.reload(DataExperimentSupport)

# %%
myExp.showBaseLimeLocalImportance()
